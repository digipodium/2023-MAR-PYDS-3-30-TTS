# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('laptops.csv')
df.head(50)
# Out:
#                                                 title     price  \
# 0   HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...    39,990
# 1   Dell Vostro 3420 Laptop,12th Gen Intel Core i3...    41,990
# 2   Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...    44,490
# 3   HP 255 G8 Laptop with AMD Athlon Silver 3050U ...    26,999
# 4   Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...    33,639
# 5   Lenovo Ideapad 3 AMD Ryzen 5 5500U 15.6" (39.6...    43,917
# 6   (Renewed) Dell Latitude E5470 Intel Core i5 6t...    17,920
# 7   HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/5...    40,490
# 8   HP 15s, 11th Gen Intel Core i3 8GB RAM/1TB HDD...    37,490
# 9   Lenovo V15 AMD Ryzen 5 5500U 15.6" (39.62cm) F...    37,999
# 10  Dell Inspiron 3511 Laptop, Intel i3-1115G4, 8G...    38,990
# 11  Apple 2023 MacBook Pro Laptop M2 Max chip with...  3,45,766
# 12  Apple 2023 MacBook Pro Laptop M2 Max chip with...  3,09,900
# 13  HP Pavilion 14 12th Gen Intel Core i5 16GB RAM...    66,990
# 14  Acer Extensa 15 Lightweight Laptop Intel Core ...    42,990
# 15  Lenovo V15 AMD Ryzen5 5500U 15.6" (39.62 cm) F...    35,990
# 16  Lenovo IdeaPad D330 Intel Celeron N4020 10.1" ...    20,990
# 17  HP 245 G8 3S7L2PA Notebook Business Laptop 14 ...    24,990
# 18  Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...    84,990
# 19  Lenovo V15 Intel Celeron N4020 15.6" (39.62 cm...    22,980
# 20  Dell Vostro 3510 Laptop, Intel Pentium Gold 75...    32,590
# 21  Fujitsu CH Intel Evo Core i5 11th Gen 13.3â€ ...    54,990
# 22  Apple 2023 MacBook Pro Laptop M2 Max chip with...  3,49,900
# 23  Dell Vostro 3420 Laptop,12th Gen Intel Core i3...    41,990
# 24  HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...    39,990
# 25  Lenovo IdeaPad Slim 1 AMD Ryzen 3 3250U 15.6" ...    36,990
# 26  Xiaomi Notebook Pro QHD+IPS AntiGlare Display ...    56,999
# 27  HP 15s AMD Ryzen 3-5300U 15.6inch(39.6cm) FHD ...    37,990
# 28  HP 15s- Ryzen 5-5500U 8GB RAM/512GB SSD 15.6 i...    45,490
# 29  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...    25,685
# 30  Acer Extensa 15 Lightweight Laptop 11th Gen In...    32,489
# 31  ASUS VivoBook 14 (2021), Intel Core i5-1035G1 ...    42,990
# 32  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...    25,990
# 33  Apple 2023 MacBook Pro Laptop M2 Max chip with...  3,45,766
# 34  Fujitsu CH Intel Evo Core i5 11th Gen 13.3â€ ...    54,990
# 35  HP Victus Gaming Latest AMD Ryzen 5 5600H Proc...    55,990
# 36  Lenovo IdeaPad Slim 3 Chromebook Intel Celeron...    15,990
# 37  Honor MagicBook X14, 11th Gen Intel Core i5-11...    46,990
# 38  ASUS VivoBook 15, Intel Core i3-1115G4 11th Ge...    35,990
# 39  HP Victus Gaming Latest 12th Gen Intel Core i7...    79,990
# 40  (Renewed) Dell Latitude Laptop 7390 Intel Core...    29,393
# 41  RedmiBook Pro Intel Core i5 11th Gen H Series ...       NaN
# 42  Dell XPS 9720 Laptop, Intel i9-12900HK, 32GB D...  3,85,578
# 43  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...    56,990
# 44  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...    64,999
# 45  Dell Vostro 3420 Laptop,12th Gen Intel Core i3...    41,990
# 46  HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...    39,990
# 47  Dell (Renewed) Latitude Intel E5440-i3-4 GB SS...    15,037
# 48  Dell Inspiron 3511 Laptop, Intel i3-1115G4, 8G...    38,990
# 49  Lenovo V15 AMD Ryzen 3 5300U 15.6" (39.62cm) F...    33,999
#
#                 rating
# 0                  NaN
# 1                  NaN
# 2   4.4 out of 5 stars
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18  4.7 out of 5 stars
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26  4.3 out of 5 stars
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35  4.3 out of 5 stars
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39  4.3 out of 5 stars
# 40                 NaN
# 41                 NaN
# 42                 NaN
# 43                 NaN
# 44                 NaN
# 45                 NaN
# 46                 NaN
# 47                 NaN
# 48                 NaN
# 49                 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   339 non-null    object
#  1   price   331 non-null    object
#  2   rating  24 non-null     object
# dtypes: object(3)
# memory usage: 8.1+ KB

# %%
print(df.columns.tolist())
# Out:
# ['title', 'price', 'rating']

# %%
def clean_price_column(price):
    if isinstance(price,str):
        price=price.replace(',','')
        price=price.strip()
        if price.isnumeric():
            price=int(price)
            return price
        if len(price)==0:
            return np.nan
    return price

# %%
clean_price_column('1,999')
# Out:
# 1999

# %%
df['cleaned_price']=df['price'].apply(clean_price_column)

# %%
def clean_rating_column(rating):
    if isinstance(rating,str):
        rating=rating.split()[0]
        return float(rating)
    return rating

# %%
df['cleaned_rating']=df['rating'].apply(clean_rating_column)

# %%
df.sort_values(by='price',ascending=False,inplace=True)

# %%
df.drop(columns=['price','rating'],inplace=True)

# %%
df
# Out:
#                                                  title  cleaned_price  \
# 129  ASUS TUF Gaming A15, 15.6" (39.62 cm) FHD 144H...        98000.0
# 104  ASUS TUF Gaming A15, 15.6" (39.62 cm) FHD 144H...        98000.0
# 160  ASUS TUF Gaming A15, 15.6" (39.62 cm) FHD 144H...        98000.0
# 179  Samsung Galaxy Book2 360 Intel 12th Gen i7 Evo...        97990.0
# 79   ASUS ROG Strix G17, 17.3-inch (43.94 cms) FHD ...        90990.0
# ..                                                 ...            ...
# 191  (renewed) Latitude D620 core 2 Duo Laptop/4 gb...            NaN
# 239  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...            NaN
# 276  (Renewed) Lenovo IdeaPad 3 11th Gen Intel Core...            NaN
# 301  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...            NaN
# 314  (Renewed) Dell Latitude Laptop E5470 Intel Cor...            NaN
#
#      cleaned_rating
# 129             4.3
# 104             4.3
# 160             4.3
# 179             4.3
# 79              4.5
# ..              ...
# 191             NaN
# 239             NaN
# 276             NaN
# 301             NaN
# 314             NaN
#
# [339 rows x 3 columns]
