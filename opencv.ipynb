# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#load and display an image
img = cv2.imread("G4qMVSo.jpg")
plt.imshow(img)

# %%
#Rotate the image
rotate_clockwise=cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
plt.imshow(rotate_clockwise)

# %%
#Rotate the image
rotate_clockwise=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(rotate_clockwise)

# %%
#Rotate the image
rotate_clockwise=cv2.rotate(img,cv2.ROTATE_180)
plt.imshow(rotate_clockwise)

# %%
#size of the image
print(img.shape)
# Out:
# (1080, 1920, 3)

# %%
#blur the image
blur = cv2.blur(img,(50,70))
plt.imshow(blur)

# %%
#Draw on image
start_point = (0, 0)
end_point = (250,250)
clr = (0,255,0)
line_thickness = 15
line = cv2.line(img, start_point, end_point, clr, line_thickness)
plt.imshow(line)

# %%
#Grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
#Threshold
ret, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
plt.imshow(thresh)

# %%
#edgedetection
edges = cv2.Canny(img,100,200)
plt.imshow(edges)
